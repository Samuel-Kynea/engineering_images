# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
asteroid = pd.read_csv(r'D:\Afinal assignment\telegram\SAM\2-DEC\Suman_asteroid_classification\neo.csv')

# %%
asteroid.head()
# Out:
#         id                 name  est_diameter_min  est_diameter_max  \
# 0  2162635  162635 (2000 SS164)          1.198271          2.679415
# 1  2277475    277475 (2005 WK4)          0.265800          0.594347
# 2  2512244   512244 (2015 YE18)          0.722030          1.614507
# 3  3596030          (2012 BV13)          0.096506          0.215794
# 4  3667127          (2014 GE35)          0.255009          0.570217
#
#    relative_velocity  miss_distance orbiting_body  sentry_object  \
# 0       13569.249224   5.483974e+07         Earth          False
# 1       73588.726663   6.143813e+07         Earth          False
# 2      114258.692129   4.979872e+07         Earth          False
# 3       24764.303138   2.543497e+07         Earth          False
# 4       42737.733765   4.627557e+07         Earth          False
#
#    absolute_magnitude  hazardous
# 0               16.73      False
# 1               20.00       True
# 2               17.83      False
# ...

# %%
asteroid = asteroid.iloc[:,2:]

# %%
asteroid
numeric = ['est_diameter_min','est_diameter_max', 'relative_velocity', 'miss_distance', 'absolute_magnitude']
categorical = ['orbiting_body','sentry_object','hazardous']

df_num = asteroid[numeric]
df_cat = asteroid[categorical]

# %%
df_num.boxplot()
plt.xticks(rotation = 90); plt.show()

# %%
df_num1 = df_num[['est_diameter_min','est_diameter_max', 'relative_velocity', 'absolute_magnitude']]
df_num1.boxplot()
plt.xticks(rotation=90); plt.show()

# %%
for i in df_cat: 
    print(i,':\n', df_cat[i].value_counts())
    print()
# Out:
# orbiting_body :
#  Earth    90836
# Name: orbiting_body, dtype: int64
#
# sentry_object :
#  False    90836
# Name: sentry_object, dtype: int64
#
# hazardous :
#  False    81996
# True      8840
# Name: hazardous, dtype: int64

# %%
df_cat.hazardous.value_counts().plot(kind='bar'); plt.xticks(rotation=0); plt.show()
